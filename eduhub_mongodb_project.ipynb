# %% [markdown]
# Imports and MongoDB Connection

# %%
from pymongo import MongoClient
from datetime import datetime
import pandas as pd
import json

# Connect to MongoDB
#client = "mongodb+srv://< eduhub_db  >:< 5d9W71bLyTJMEwNN  >@cluster0.bkcxczk.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
#db = client["eduhub_db"]

MONGO_URI = "mongodb+srv://< eduhub_db  >:< 5d9W71bLyTJMEwNN  >@cluster0.bkcxczk.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
DB_NAME = "eduhub_db"

client = MongoClient(MONGO_URI)
db = client[DB_NAME]

print("Connected to MongoDB:", db)
# Out:
# Connected to MongoDB: Database(MongoClient(host=['ac-2wgegys-shard-00-01.bkcxczk.mongodb.net:27017', 'ac-2wgegys-shard-00-00.bkcxczk.mongodb.net:27017', 'ac-2wgegys-shard-00-02.bkcxczk.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-rnj2e2-shard-0', tls=True), 'eduhub_db')

# %% [markdown]
# Create Collections with Validation

# %%
# Example schema validation for users collection
user_validator = {
    "$jsonSchema": {
        "bsonType": "object",
        "required": ["userId", "email", "firstName", "lastName", "role"],
        "properties": {
            "userId": {"bsonType": "string"},
            "email": {"bsonType": "string"},
            "firstName": {"bsonType": "string"},
            "lastName": {"bsonType": "string"},
            "role": {
                "bsonType": "string",
                "enum": ["student", "instructor"]
            },
            "dateJoined": {"bsonType": "date"},
            "isActive": {"bsonType": "bool"}
        }
    }
}

db.create_collection("users", validator=user_validator)
db.create_collection("courses")
db.create_collection("enrollments")
db.create_collection("lessons")
db.create_collection("assignments")
db.create_collection("submissions")

print("Collections created with schema validation!")
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[9], line 21
#       1 # Example schema validation for users collection
#       2 user_validator = {
#       3     "$jsonSchema": {
#       4         "bsonType": "object",
#    (...)
#      18     }
#      19 }
# ---> 21 db.create_collection("users", validator=user_validator)
#      22 db.create_collection("courses")
#      23 db.create_collection("enrollments")
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\database.py:619, in Database.create_collection(self, name, codec_options, read_preference, write_concern, read_concern, session, check_exists, **kwargs)
#     611     common.validate_is_mapping("clusteredIndex", clustered_index)
#     613 with self._client._tmp_session(session) as s:
#     614     # Skip this check in a transaction where listCollections is not
#     615     # supported.
#     616     if (
#     617         check_exists
#     618         and (not s or not s.in_transaction)
# --> 619         and name in self._list_collection_names(filter={"name": name}, session=s)
#     620     ):
#     621         raise CollectionInvalid("collection %s already exists" % name)
#     622     coll = Collection(
#     623         self,
#     624         name,
#    (...)
#     629         read_concern,
#     630     )
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\database.py:1205, in Database._list_collection_names(self, session, filter, comment, **kwargs)
#    1201     if not filter or (len(filter) == 1 and "name" in filter):
#    1202         kwargs["nameOnly"] = True
#    1204 return [
# -> 1205     result["name"] for result in self._list_collections_helper(session=session, **kwargs)
#    1206 ]
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\database.py:1143, in Database._list_collections_helper(self, session, filter, comment, **kwargs)
#    1135 def _cmd(
#    1136     session: Optional[ClientSession],
#    1137     _server: Server,
#    1138     conn: Connection,
#    1139     read_preference: _ServerMode,
#    1140 ) -> CommandCursor[MutableMapping[str, Any]]:
#    1141     return self._list_collections(conn, session, read_preference=read_preference, **kwargs)
# -> 1143 return self._client._retryable_read(
#    1144     _cmd, read_pref, session, operation=_Op.LIST_COLLECTIONS
#    1145 )
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:2047, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2042 # Ensure that the client supports retrying on reads and there is no session in
#    2043 # transaction, otherwise, we will not support retry behavior for this call.
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
# -> 2047 return self._retry_internal(
#    2048     func,
#    2049     session,
#    2050     None,
#    2051     operation,
#    2052     is_read=True,
#    2053     address=address,
#    2054     read_pref=read_pref,
#    2055     retryable=retryable,
#    2056     operation_id=operation_id,
#    2057 )
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:2003, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
# -> 2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
#    2014     ).run()
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:2912, in _ClientConnectionRetryable._read(self)
#    2910 self._server = self._get_server()
#    2911 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2912 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2913     conn,
#    2914     read_pref,
#    2915 ):
#    2916     if self._retrying and not self._retryable:
#    2917         self._check_last_error()
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\contextlib.py:117, in _GeneratorContextManager.__enter__(self)
#     115 del self.args, self.kwds, self.func
#     116 try:
# --> 117     return next(self.gen)
#     118 except StopIteration:
#     119     raise RuntimeError("generator didn't yield") from None
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:1867, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1858 # Get a connection for a server matching the read preference, and yield
#    1859 # conn with the effective read preference. The Server Selection
#    1860 # Spec says not to send any $readPreference to standalones and to
#    (...)
#    1864 # NOTE: We already opened the Topology when selecting a server so there's no need
#    1865 # to call _get_topology() again.
#    1866 single = self._topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1867 with self._checkout(server, session) as conn:
#    1868     if single:
#    1869         if conn.is_repl and not (session and session.in_transaction):
#    1870             # Use primary preferred to ensure any repl set member
#    1871             # can handle the request.
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\contextlib.py:117, in _GeneratorContextManager.__enter__(self)
#     115 del self.args, self.kwds, self.func
#     116 try:
# --> 117     return next(self.gen)
#     118 except StopIteration:
#     119     raise RuntimeError("generator didn't yield") from None
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:1777, in MongoClient._checkout(self, server, session)
#    1775     yield session._pinned_connection
#    1776     return
# -> 1777 with server.checkout(handler=err_handler) as conn:
#    1778     # Pin this session to the selected server or connection.
#    1779     if (
#    1780         in_txn
#    1781         and session
#    (...)
#    1786         )
#    1787     ):
#    1788         session._pin(server, conn)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\contextlib.py:117, in _GeneratorContextManager.__enter__(self)
#     115 del self.args, self.kwds, self.func
#     116 try:
# --> 117     return next(self.gen)
#     118 except StopIteration:
#     119     raise RuntimeError("generator didn't yield") from None
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\pool.py:1118, in Pool.checkout(self, handler)
#    1109 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1110     _debug_log(
#    1111         _CONNECTION_LOGGER,
#    1112         message=_ConnectionStatusMessage.CHECKOUT_STARTED,
#    (...)
#    1115         serverPort=self.address[1],
#    1116     )
# -> 1118 conn = self._get_conn(checkout_started_time, handler=handler)
#    1120 duration = time.monotonic() - checkout_started_time
#    1121 if self.enabled_for_cmap:
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\pool.py:1280, in Pool._get_conn(self, checkout_started_time, handler)
#    1278 else:  # We need to create a new connection
#    1279     try:
# -> 1280         conn = self.connect(handler=handler)
#    1281     finally:
#    1282         with self._max_connecting_cond:
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\pool.py:1072, in Pool.connect(self, handler)
#    1069     if handler:
#    1070         handler.contribute_socket(conn, completed_handshake=False)
# -> 1072     conn.authenticate()
#    1073 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1074 except BaseException:
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\pool.py:525, in Connection.authenticate(self, reauthenticate)
#     522 if creds:
#     523     from pymongo.synchronous import auth
# --> 525     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     526 self.ready = True
#     527 duration = time.monotonic() - self.creation_time
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\auth.py:450, in authenticate(credentials, conn, reauthenticate)
#     448     _authenticate_oidc(credentials, conn, reauthenticate)
#     449 else:
# --> 450     auth_func(credentials, conn)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\auth.py:355, in _authenticate_default(credentials, conn)
#     353         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354     else:
# --> 355         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356 else:
#     357     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\auth.py:96, in _authenticate_scram(credentials, conn, mechanism)
#      94 else:
#      95     nonce, first_bare, cmd = _authenticate_scram_start(credentials, mechanism)
# ---> 96     res = conn.command(source, cmd)
#      98 assert res is not None
#      99 server_first = res["payload"]
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\pool.py:413, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411     self._raise_if_not_writable(unacknowledged)
#     412 try:
# --> 413     return command(
#     414         self,
#     415         dbname,
#     416         spec,
#     417         self.is_mongos,
#     418         read_preference,
#     419         codec_options,  # type: ignore[arg-type]
#     420         session,
#     421         client,
#     422         check,
#     423         allowable_errors,
#     424         self.address,
#     425         listeners,
#     426         self.max_bson_size,
#     427         read_concern,
#     428         parse_write_concern_error=parse_write_concern_error,
#     429         collation=collation,
#     430         compression_ctx=self.compression_context,
#     431         use_op_msg=self.op_msg_enabled,
#     432         unacknowledged=unacknowledged,
#     433         user_fields=user_fields,
#     434         exhaust_allowed=exhaust_allowed,
#     435         write_concern=write_concern,
#     436     )
#     437 except (OperationFailure, NotPrimaryError):
#     438     raise
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\helpers_shared.py:284, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 284 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : Authentication failed., full error: {'ok': 0, 'errmsg': 'bad auth : Authentication failed.', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
# Load and Insert Sample Data

# %%
with open("sample_data.json") as f:
    sample_data = json.load(f)

db.users.insert_many(sample_data["users"])
db.courses.insert_many(sample_data["courses"])
db.enrollments.insert_many(sample_data["enrollments"])
db.lessons.insert_many(sample_data["lessons"])
db.assignments.insert_many(sample_data["assignments"])
db.submissions.insert_many(sample_data["submissions"])

print("Sample data inserted!")
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[11], line 4
#       1 with open("sample_data.json") as f:
#       2     sample_data = json.load(f)
# ----> 4 db.users.insert_many(sample_data["users"])
#       5 db.courses.insert_many(sample_data["courses"])
#       6 db.enrollments.insert_many(sample_data["enrollments"])
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)
#     600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:2082, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2068 """Execute an operation with consecutive retries if possible
#    2069
#    2070 Returns func()'s return value on success. On error retries the same
#    (...)
#    2079 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2080 """
#    2081 with self._tmp_session(session) as s:
# -> 2082     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:2003, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
# -> 2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
#    2014     ).run()
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:2876, in _ClientConnectionRetryable._write(self)
#    2874 is_mongos = False
#    2875 self._server = self._get_server()
# -> 2876 with self._client._checkout(self._server, self._session) as conn:
#    2877     max_wire_version = conn.max_wire_version
#    2878     sessions_supported = (
#    2879         self._session
#    2880         and self._server.description.retryable_writes_supported
#    2881         and conn.supports_sessions
#    2882     )
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\contextlib.py:117, in _GeneratorContextManager.__enter__(self)
#     115 del self.args, self.kwds, self.func
#     116 try:
# --> 117     return next(self.gen)
#     118 except StopIteration:
#     119     raise RuntimeError("generator didn't yield") from None
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\mongo_client.py:1777, in MongoClient._checkout(self, server, session)
#    1775     yield session._pinned_connection
#    1776     return
# -> 1777 with server.checkout(handler=err_handler) as conn:
#    1778     # Pin this session to the selected server or connection.
#    1779     if (
#    1780         in_txn
#    1781         and session
#    (...)
#    1786         )
#    1787     ):
#    1788         session._pin(server, conn)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\contextlib.py:117, in _GeneratorContextManager.__enter__(self)
#     115 del self.args, self.kwds, self.func
#     116 try:
# --> 117     return next(self.gen)
#     118 except StopIteration:
#     119     raise RuntimeError("generator didn't yield") from None
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\pool.py:1118, in Pool.checkout(self, handler)
#    1109 if self.enabled_for_logging and _CONNECTION_LOGGER.isEnabledFor(logging.DEBUG):
#    1110     _debug_log(
#    1111         _CONNECTION_LOGGER,
#    1112         message=_ConnectionStatusMessage.CHECKOUT_STARTED,
#    (...)
#    1115         serverPort=self.address[1],
#    1116     )
# -> 1118 conn = self._get_conn(checkout_started_time, handler=handler)
#    1120 duration = time.monotonic() - checkout_started_time
#    1121 if self.enabled_for_cmap:
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\pool.py:1280, in Pool._get_conn(self, checkout_started_time, handler)
#    1278 else:  # We need to create a new connection
#    1279     try:
# -> 1280         conn = self.connect(handler=handler)
#    1281     finally:
#    1282         with self._max_connecting_cond:
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\pool.py:1072, in Pool.connect(self, handler)
#    1069     if handler:
#    1070         handler.contribute_socket(conn, completed_handshake=False)
# -> 1072     conn.authenticate()
#    1073 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1074 except BaseException:
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\pool.py:525, in Connection.authenticate(self, reauthenticate)
#     522 if creds:
#     523     from pymongo.synchronous import auth
# --> 525     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     526 self.ready = True
#     527 duration = time.monotonic() - self.creation_time
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\auth.py:450, in authenticate(credentials, conn, reauthenticate)
#     448     _authenticate_oidc(credentials, conn, reauthenticate)
#     449 else:
# --> 450     auth_func(credentials, conn)
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\auth.py:355, in _authenticate_default(credentials, conn)
#     353         return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354     else:
# --> 355         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356 else:
#     357     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\auth.py:96, in _authenticate_scram(credentials, conn, mechanism)
#      94 else:
#      95     nonce, first_bare, cmd = _authenticate_scram_start(credentials, mechanism)
# ---> 96     res = conn.command(source, cmd)
#      98 assert res is not None
#      99 server_first = res["payload"]
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\pool.py:413, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     411     self._raise_if_not_writable(unacknowledged)
#     412 try:
# --> 413     return command(
#     414         self,
#     415         dbname,
#     416         spec,
#     417         self.is_mongos,
#     418         read_preference,
#     419         codec_options,  # type: ignore[arg-type]
#     420         session,
#     421         client,
#     422         check,
#     423         allowable_errors,
#     424         self.address,
#     425         listeners,
#     426         self.max_bson_size,
#     427         read_concern,
#     428         parse_write_concern_error=parse_write_concern_error,
#     429         collation=collation,
#     430         compression_ctx=self.compression_context,
#     431         use_op_msg=self.op_msg_enabled,
#     432         unacknowledged=unacknowledged,
#     433         user_fields=user_fields,
#     434         exhaust_allowed=exhaust_allowed,
#     435         write_concern=write_concern,
#     436     )
#     437 except (OperationFailure, NotPrimaryError):
#     438     raise
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\synchronous\network.py:212, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210             client._process_response(response_doc, session)
#     211         if check:
# --> 212             helpers_shared._check_command_response(
#     213                 response_doc,
#     214                 conn.max_wire_version,
#     215                 allowable_errors,
#     216                 parse_write_concern_error=parse_write_concern_error,
#     217             )
#     218 except Exception as exc:
#     219     duration = datetime.datetime.now() - start
#
# File c:\users\winma\appdata\local\programs\python\python39\lib\site-packages\pymongo\helpers_shared.py:284, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error, pool_opts)
#     281 elif code == 43:
#     282     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 284 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: bad auth : Authentication failed., full error: {'ok': 0, 'errmsg': 'bad auth : Authentication failed.', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
# CRUD: Create Operations

# %%
# Add a new student
new_student = {
    "userId": "stu_21",
    "email": "student21@eduhub.com",
    "firstName": "John",
    "lastName": "Doe",
    "role": "student",
    "dateJoined": datetime.now(),
    "isActive": True
}
db.users.insert_one(new_student)

# Create a new course
new_course = {
    "courseId": "c_09",
    "title": "Data Science Basics",
    "instructorId": "inst_02",
    "category": "Data Science",
    "level": "beginner",
    "duration": 12,
    "price": 99,
    "tags": ["python", "ml"],
    "createdAt": datetime.now(),
    "isPublished": False
}
db.courses.insert_one(new_course)

# %% [markdown]
# CRUD: Read Operations

# %%
# Find all active students
active_students = list(db.users.find({"role": "student", "isActive": True}))
pd.DataFrame(active_students)

# Retrieve course details with instructor info
course_details = list(db.courses.aggregate([
    {"$lookup": {
        "from": "users",
        "localField": "instructorId",
        "foreignField": "userId",
        "as": "instructor_info"
    }}
]))
pd.DataFrame(course_details)

# %% [markdown]
# CRUD: Update Operations

# %%
# Update user profile
db.users.update_one(
    {"userId": "stu_21"},
    {"$set": {"profile": {"bio": "Enthusiastic learner", "skills": ["Python", "SQL"]}}}
)

# Publish a course
db.courses.update_one({"courseId": "c_09"}, {"$set": {"isPublished": True}})

# %% [markdown]
# CRUD: Delete Operations

# %%
# Soft delete user
db.users.update_one({"userId": "stu_21"}, {"$set": {"isActive": False}})

# Delete an enrollment
db.enrollments.delete_one({"studentId": "stu_05", "courseId": "c_01"})

# %% [markdown]
# Aggregation Example

# %%
# Total enrollments per course
enrollment_stats = list(db.enrollments.aggregate([
    {"$group": {"_id": "$courseId", "total_students": {"$sum": 1}}}
]))
pd.DataFrame(enrollment_stats)

# %% [markdown]
# Indexing

# %%
db.users.create_index("email", unique=True)
db.courses.create_index([("title", "text"), ("category", 1)])
print("Indexes created!")
